# %% [markdown]
# <a href="https://colab.research.google.com/github/RoksanaMaya/MLGrit/blob/main/Amazon_Product_Review/1_Data_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path='/content/drive/MyDrive/Colab Notebooks'
data=path+'/All_Beauty.json'

# %%
df = pd.read_json(data, lines=True)

# %%
df.head().T
# Out:
#                                 0  \
# overall                         1
# verified                     True
# reviewTime            02 19, 2015
# reviewerID         A1V6B6TNIC10QE
# asin                   0143026860
# reviewerName    theodore j bigham
# reviewText                  great
# summary                  One Star
# unixReviewTime         1424304000
# vote                          NaN
# style                         NaN
# image                         NaN
#
#                                                                 1  \
# overall                                                         4
# verified                                                     True
# reviewTime                                            12 18, 2014
# reviewerID                                         A2F5GHSXFQ0W6J
# asin                                                   0143026860
# reviewerName                                         Mary K. Byke
# ...

# %%
df.tail()
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 371340        1      True  07 20, 2017  A202DCI7TV1022  B01HJEGTYK
# 371341        5      True  03 16, 2017  A3FSOR5IJOFIBE  B01HJEGTYK
# 371342        5      True   03 1, 2017  A1B5DK6CTP2P24  B01HJEGTYK
# 371343        2      True  02 21, 2017  A23OUYS5IRMJS9  B01HJEGTYK
# 371344        2      True  12 15, 2016  A24KQ9RVU81L87  B01HJEGTYK
#
#           reviewerName                                         reviewText  \
# 371340             Sam  It was awful. It was super frizzy and I tried ...
# 371341             TYW  I was skeptical about buying this.  Worried it...
# 371342  Norma Jennings                           Makes me look good fast.
# 371343             Lee  Way lighter than photo\nNot mix blend of color...
# 371344       Season341  No return instructions/phone # in packaging.  ...
#
#                                                   summary  unixReviewTime  \
# ...

# %%
df.columns
# Out:
# Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'style', 'image'],
#       dtype='object')

# %%
df.drop(columns=['reviewerID', 'asin', 'reviewerName', 'unixReviewTime', 'vote', 'style', 'image'], inplace=True)

# %%
df.to_parquet(path+'/All_Beauty_v2.parquet', index=False)
